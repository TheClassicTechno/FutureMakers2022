# %% [markdown]
# <a href="https://colab.research.google.com/github/TheClassicTechno/FutureMakers2022/blob/main/day2/Julia_Huang_Day_2_Intro_to_Machine_Learning_SV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Day 2 Objectives:
# * To introduce you to some basic Machine Learning (ML) concepts and models.
# * To build your ML model development skills.

# %% [markdown]
# # Machine Learning
#
# Machine learning is a subfield of artificial intelligence (AI) that enables systems to automatically learn and improve from examples and experience (aka data), without being explicitly programmed.

# %% [markdown]
# ## Supervised Learning
#
# Machines often learn from sample data that has both an example input and an example output. For example, a data input-output sample pair may be input data about an individual’s credit history, and their corresponding credit risk (either specified by a human expert or based on historical outcomes). Given enough of these input-output samples, the machine learns how to construct a “model“ (i.e., a logic or algorithm) that represents the relationship between an individual's credit history and how 'risky' they might be considered from a credit perspective, based on the samples it has seen.
#
# This class of machine learning is called “supervised learning”, since along with the input data, the desired outcome is also given, and the model is “supervised” or guided by the outcome in learning the associated model parameters.
#
# There are 2 types of supervised learning approaches: a) **Regression** , b) **Classification** [Source](https://medium.com/machine-learning-in-practice/a-gentle-introduction-to-machine-learning-concepts-cfe710910eb)
#
# ![image_2021-10-31_200632.png](data:image/png;base64,...)

# %% [markdown]
# ## Unsupervised Learning
#
# Another form of machine learning is "unsupervised learning". In unsupervised learning, the machine learns from data for which the outcomes are not known. It’s given input samples, but no output samples.
#
# There are 2 types of unsupervised learning approaches: a) **Clustering**, b) **Dimensionality Reduction** [Source](https://medium.com/machine-learning-in-practice/a-gentle-introduction-to-machine-learning-concepts-cfe710910eb)
#
# ![image_2021-10-31_201022.png](data:image/png;base64,...)

# %% [markdown]
# ##Semi-supervised Learning
#
# Supervised and unsupervised learning each have their pros and cons. Supervised learning is typically demanding from the standpoint of acquiring enough input-output labeled data for learning, while unsupervised learning is relatively less demanding in that regard because it only needs input data but its outcomes can be unpredictable.
#
# A middle ground is semi-supervised learning. In semi-supervised learning, a model uses the larger  unlabeled data to gain a general sense of the data’s structure, and a much smaller subset of labeled data to learn how to group and organize the whole dataset. [Source](https://medium.com/machine-learning-in-practice/a-gentle-introduction-to-machine-learning-concepts-cfe710910eb)

# %% [markdown]
# ## Reinforcement Learning
#
# Reinforcement learning is like unsupervised learning in the sense that outputs are usually not given.
#
# The central concept of reinforcement learning is based around an “agent” (a computer or robot) that is interacting with an “environment” (here defined as everything that is not the agent).
#
# The agent performs actions on the environment (for instance, a robot takes a step forward). Then, the environments will then provide some sort of feedback to the agent, usually in a form called the “reward.” [Source](https://medium.com/machine-learning-in-practice/a-gentle-introduction-to-machine-learning-concepts-cfe710910eb)
#
# While supervised learning is about instructive feedback, reinforcement learning is about **evaluative feedback**.

# %% [markdown]
# # Machine Learning with Scikit-Learn
#
# [Source](https://towardsdatascience.com/an-introduction-to-scikit-learn-the-gold-standard-of-python-machine-learning-e2b9238a98ab)
#
# Scikit-learn provides a **wide selection** of supervised and unsupervised learning algorithms.

# %% [markdown]
# ## The data and math libraries in Python that you should be aware of are the following:
#
# 1. [NumPy](http://www.numpy.org/): For any work with matrices, especially math operations
# 2. [SciPy](https://www.scipy.org/): Scientific and technical computing
# 3. [Matplotlib](https://matplotlib.org/): Data visualisation
# 4. [IPython](https://ipython.org/): Interactive console for Python
# 5. [Sympy](https://www.sympy.org/en/index.html): Symbolic mathematics
# 6. [Pandas](https://pandas.pydata.org/): Data handling, manipulation, and analysis
#
# Scikit Learn is focused on Machine Learning, e.g data modelling. It is *not* concerned with the loading, handling, manipulating, and visualising of data. Thus, it is natural and common practice to use the above libraries, especially NumPy, for those extra steps. Scikit learn and NumPy are made for each other!

# %%
from sklearn.datasets import load_iris
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Iris data sets consists of 3 different types of irises’ (Setosa, Versicolour, and Virginica) petal and sepal length, stored in a 150x4 numpy.ndarray
#
# The rows represent the samples. The columns represent the attribtes (also called features) of the samples: Sepal Length, Sepal Width, Petal Length and Petal Width.

# %%
# Load in our dataset
iris_data = load_iris()

# %% [markdown]
# Let's visualize the data first

# %%
import matplotlib.pyplot as plt

# %%
# we only take the first two features.
X = iris_data.data[:, :2]  
# we get all the target for each sample
y = iris_data.target       

# we get minimum and maximum values so that we know what should be plot axis ticks 
# (this is only for visualization purpose)
x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5  
# we get minimum and maximum values so that we know what should be plot axis ticks 
# (this is only for visualization purpose)
y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5  

# we will be creating 2 figures, each of size 8 x 6 dpi
plt.figure(2, figsize=(8, 6))   
# clear any previous figures (if any), and make this the current figure
plt.clf()                       

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1)
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())
plt.title('Red = Setosa, Yellow = Versicolour, Gray = Virginica')

plt.show()

# %% [markdown]
# ## Question 1
#
# What are the 2 features of each sample of the **iris_dataset** on which above visualization has been done?
# #My answer: sepal length and sepal width
#
# What are the two additional features of this dataset?
# #My answer: Petal Length and Petal Width

# %%
""" Enter your code for Question 1 here """
# Out:
# ' Enter your code for Question 1 here '

# %% [markdown]
# ## Question 2
#
# In the cells above, we have visualized 2 features of **iris_data** (sepal width and sepal length) for all 3 types of irises. Now you have to visualize the other 2 features of **iris_data** for all 3 types of irises. (hint: refer to the vizualization steps above) What are your observations?
# #my answer: versicolour and virginia have bigger petal lengths and widths than setosa

# %%
""" Enter your code for Question 2 here """
# we only take the first two features.
X = iris_data.data[:, 2:4]  
# we get all the target for each sample
y = iris_data.target       

# we get minimum and maximum values so that we know what should be plot axis ticks 
# (this is only for visualization purpose)
x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5  
# we get minimum and maximum values so that we know what should be plot axis ticks 
# (this is only for visualization purpose)
y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5  

# we will be creating 2 figures, each of size 8 x 6 dpi
plt.figure(2, figsize=(8, 6))   
# clear any previous figures (if any), and make this the current figure
plt.clf()                       

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1)
plt.xlabel("Petal length")
plt.ylabel("Petal width")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())
plt.title('Red = Setosa, Yellow = Versicolour, Gray = Virginica')

plt.show()

# %% [markdown]
# # Decision Trees
#
# Decision trees for both classification and regression are super easy to use in Scikit Learn with a built in class.
#
# We’ll initialise our decision tree for classification, which is also a built in class.

# %%
# Initialize our decision tree object
classification_tree = tree.DecisionTreeClassifier()

# %% [markdown]
# Running training is then a simple one-liner! The $.fit(X, Y)$ function trains the model where X is the NumPy array of inputs and Y is the corresponding NumPy array of outputs.

# %%
# Train our decision tree (tree induction + pruning)
classification_tree = classification_tree.fit(iris_data.data, iris_data.target)

# %% [markdown]
# # Graphviz
#
# You have been acquainted with **Matplotlib**, now let's use a different visualization library in Python: **Graphviz**

# %%
import graphviz

# %% [markdown]
# Graphviz comes with a few options that will help in visualising the decision nodes and splits that the model learned which is super useful for understanding how it all works.

# %%
dot_data = tree.export_graphviz(classification_tree, out_file=None, feature_names=iris_data.feature_names, class_names=iris_data.target_names, filled=True, rounded=True, special_characters=True)

# %% [markdown]
# Render the decision tree in a .pdf file

# %%
graph = graphviz.Source(dot_data)  
graph.render("iris")
# Out:
# 'iris.pdf'

# %% [markdown]
# Install the following libraries so that you can open a .pdf file in Colab Notebooks.

# %%
! pip install pdf2image
! apt-get install poppler-utils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 62 not upgraded.
# Need to get 154 kB of archives.
# After this operation, 613 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 poppler-utils amd64 0.62.0-2ubuntu2.12 [154 kB]
# Fetched 154 kB in 0s (698 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 155639 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking poppler-utils (0.62.0-2ubuntu2.12) ...
# ...

# %% [markdown]
# We use the following code to open the .pdf file in Colab, by first converting it into a .png image
#
# Below we will colour the nodes based on the feature names and display the class and feature information of each node.

# %%
from pdf2image import convert_from_path
from IPython.display import display, Image

images = convert_from_path("/content/iris.pdf")
for i, image in enumerate(images):    
    fname = "image" + str(i) + ".png"
    image.save(fname, "PNG")
Image(fname, width=800, height=500)

# %% [markdown]
# ## Question 3
#
# In the above image, you see a reference to an attribute "gini" in every node of the decision tree. Do some web research and write down what the attribute "gini" is, how is it measured and in which classification approaches besides Decision trees is it used?
#
# #my answer: Gini index calculates the amount of probability of a specific feature that is classified incorrectly when selected randomly. An attribute with a lower Gini index should be preferred. The Gini index s calculated by subtracting the sum of the squared probabilities of each class from one. It is used with classification trees to measure how impure the information in a node is. It helps determine which questions to ask in each node to classify categories (e.g. zebra) in the most effective way possible. Gini index is also used with logistc regression, regression trees, financial credit prediction models, random forests, etc.

# %% [markdown]
# # Linear Regression
#
# Just like Decision Tree, Linear Regression is another type of Machine Learning model you will see in the upcoming days.
#
# Linear regression attempts to model the relationship between two variables by fitting a linear equation (= a straight line) to the observed data. One variable is considered to be an explanatory variable (e.g. your income), and the other is considered to be a dependent variable (e.g. your expenses).

# %% [markdown]
# ## Question 4
#
# We have used Decision Tree to classify the features into 3 types of irises. Can we use Linear Regression in place of Decision Tree? Explain your answer.
#
# #my answer: No you can only use linear regresion for 2 variables (1 independent and one dependent) when in this case you have 3 iris types.

# %% [markdown]
# # See a Forest for the Trees
#
# Read about the Random Forest [here](https://scikit-learn.org/stable/modules/ensemble.html#forests-of-randomized-trees) before you go forward.

# %% [markdown]
# ## Question 5
#
# Create a Random Forest Classifier by filling in the code scaffolding provided below, using functions you learned after reading the above documentation. Did you encounter any issues during the implementation? If so, please discuss with your team and mentor, or share in the #QA channel.
#
# #my answer: I encountered one code problem regarding .export_graphviz() in line 48. I will discuss this with other members.

# %%
from sklearn.ensemble import RandomForestClassifier

# Instantiate the Random Forest Classifier here


forest = RandomForestClassifier(n_estimators=10)


# Fit the Random Forest Classifier here
forestTrainer = forest.fit(iris_data.data, iris_data.target)
estimator=forestTrainer.estimators_[5]

# %% [markdown]
# You need to write some code to visualize the Random Forest you just trained. Scroll up and see how it was done for visualizing the Iris classification Decision Tree.

# %%
#dot_data = tree.export_graphviz(forestTrainer, out_file=None, feature_names=iris_data.feature_names, class_names=iris_data.target_names, filled=True, rounded=True, special_characters=True)  



dot_data = tree.export_graphviz(estimator, out_file=None, feature_names=iris_data.feature_names, class_names=iris_data.target_names, filled=True, rounded=True, special_characters=True)

# %%
dot_data = tree.export_graphviz(forest.estimators_[5], out_file=None, feature_names=iris_data.feature_names, class_names=iris_data.target_names, filled=True, rounded=True, special_characters=True)

# %% [markdown]
# We use the same code for visualizing the Random Forest as we did for the Decision Tree.

# %%
graph = graphviz.Source(dot_data)  
graph.render("iris_forest")
# Out:
# 'iris_forest.pdf'

# %%
from pdf2image import convert_from_path
from IPython.display import display, Image

images = convert_from_path("/content/iris_forest.pdf")
for i, image in enumerate(images):    
    fname = "image" + str(i) + ".png"
    image.save(fname, "PNG")
Image(fname, width=500, height=600)

# %% [markdown]
# ## Question 6
#
# What are the main similiarities and differences betweem Random Forest and Decision Trees? (Observe, research and/or discuss with team.)
#
# #my answer:  The forest has almost the same hyperparameters as a decision tree. The random forest builds many individual decision trees and then averages these predictions so it is much less likely to be affected by outliers than a single decision tree. But random forest with many trees can make the algorithm too slow and inefficient for real-time prediction. And since random forests use only a few predictors to build each decision tree, the final decision trees tend to be decorrelated, meaning that the random forest algorithm model is unlikely to outperform the dataset. On the other hand, decision trees usually overwrite the training data - meaning they are more likely to match the "noise" in the dataset than the actual underlying model. But random forests are most widely used in the real world since they are usually more accurate (since more trees improve performance and make predictions more stable). The downside of the random forest algorithm is that you can't visualize the final model, and if you don't have enough processing power or the dataset you're working with is very large. They can take a long time to create. The benefit of a simple decision tree is that the model is easy to interpret.

# %% [markdown]
# # **Upload this Day 2 Colab Notebook to your Github repository under "Day 2" folder. And add your *Reflection* on today's learning in README.md**

# %% [markdown]
# # Fun Resource
# https://app.learney.me/
#
# Fun map to learn connected Machine Learning concepts.

# %% [markdown]
# ## Bonus Question
#
# Pick a classifier from [here](https://scikit-learn.org/stable/supervised_learning.html#supervised-learning) and classify the **iris_data**. Compare the classification performance with Decision Tree and Random Forest.
#
#
# #my answer: I picked Gaussian Naive Bayes which got 71/75 accuracy(0.9466). The random forest(0.9822666) and decision tree (0.92) classifiers also got high accuracy.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d"
     % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 75 points : 4

# %%
iris_data = load_iris()
train_data, test_data, train_targets, test_targets = train_test_split(iris_data.data, iris_data.target, test_size=0.2, random_state=0)
print(train_data.shape, test_data.shape, train_targets.shape, test_targets.shape)
# Out:
# (120, 4) (30, 4) (120,) (30,)

# %%
decision_tree_predictions = classification_tree.predict(test_data)
random_forest_predictions = forest.predict(test_data)
gnb_predictions = gnb.predict(test_data)

decision_tree_correct_rate = (decision_tree_predictions == test_targets).astype(int).sum()/0.3
random_forest_correct_rate = (decision_tree_predictions == test_targets).astype(int).sum()/0.3
gnb_correct_rate = (gnb_predictions == test_targets).astype(int).sum()/0.3

print(f"decision tree correct rate: {decision_tree_correct_rate}%")
print(f"random forest correct rate: {random_forest_correct_rate}%")
print(f"gnb tree correct rate: {gnb_correct_rate}%")
# Out:
# decision tree correct rate: 100.0%
# random forest correct rate: 100.0%
# gnb tree correct rate: 96.66666666666667%

# %% [markdown]
# Source:
#
# https://towardsdatascience.com/an-introduction-to-scikit-learn-the-gold-standard-of-python-machine-learning-e2b9238a98ab
#
# https://medium.com/machine-learning-in-practice/a-gentle-introduction-to-machine-learning-concepts-cfe710910eb
